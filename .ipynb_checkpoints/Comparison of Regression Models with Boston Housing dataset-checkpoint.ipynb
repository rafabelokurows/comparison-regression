# %% [markdown]
# # Comparison of Regression Models on Boston Housing dataset

# %% [markdown]
# Inspired by:
# https://www.kaggle.com/hokleang/006-exercice-maisons-boston
# https://www.kaggle.com/betimbalamur/the-boston-house-prices-regression-analyses

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
from collections import Counter
from IPython.core.display import display, HTML
sns.set_style('darkgrid')
# %matplotlib inline
import seaborn as sbn
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %%
from sklearn.datasets import load_boston
boston_dataset = load_boston()
df = pd.DataFrame(boston_dataset.data, columns = boston_dataset.feature_names)

# %% [markdown]
# First, we load packages needed and import the data through sklearn

# %% [markdown]
# # Data checking

# %%
df.head()
# Out:
#       CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0  0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1  0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2  0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3  0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4  0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
#
#    PTRATIO       B  LSTAT  MEDV
# 0     15.3  396.90   4.98  24.0
# 1     17.8  396.90   9.14  21.6
# 2     17.8  392.83   4.03  34.7
# 3     18.7  394.63   2.94  33.4
# 4     18.7  396.90   5.33  36.2

# %%
df.describe()
# Out:
#              CRIM          ZN       INDUS        CHAS         NOX          RM  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean     3.613524   11.363636   11.136779    0.069170    0.554695    6.284634
# std      8.601545   23.322453    6.860353    0.253994    0.115878    0.702617
# min      0.006320    0.000000    0.460000    0.000000    0.385000    3.561000
# 25%      0.082045    0.000000    5.190000    0.000000    0.449000    5.885500
# 50%      0.256510    0.000000    9.690000    0.000000    0.538000    6.208500
# 75%      3.677083   12.500000   18.100000    0.000000    0.624000    6.623500
# max     88.976200  100.000000   27.740000    1.000000    0.871000    8.780000
#
#               AGE         DIS         RAD         TAX     PTRATIO           B  \
# count  506.000000  506.000000  506.000000  506.000000  506.000000  506.000000
# mean    68.574901    3.795043    9.549407  408.237154   18.455534  356.674032
# ...

# %%
df.info
# Out:
# <bound method DataFrame.info of         CRIM    ZN  INDUS  CHAS    NOX     RM   AGE     DIS  RAD    TAX  \
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  7.147  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      PTRATIO       B  LSTAT  MEDV
# 0       15.3  396.90   4.98  24.0
# ...

# %%
df['MEDV'] = boston_dataset.target
df['MEDV']
# Out:
# 0      24.0
# 1      21.6
# 2      34.7
# 3      33.4
# 4      36.2
#        ...
# 501    22.4
# 502    20.6
# 503    23.9
# 504    22.0
# 505    11.9
# Name: MEDV, Length: 506, dtype: float64

# %% [markdown]
# Then, we add a column for the target variable

# %%
df.shape
# Out:
# (506, 14)

# %%
df.isnull().sum()
# Out:
# CRIM       0
# ZN         0
# INDUS      0
# CHAS       0
# NOX        0
# RM         0
# AGE        0
# DIS        0
# RAD        0
# TAX        0
# PTRATIO    0
# B          0
# LSTAT      0
# MEDV       0
# dtype: int64

# %% [markdown]
# There are no missing values

# %%
X = df.iloc[:, 0:13].values
y = df.iloc[:, 13].values.reshape(-1,1)

# %%
X.shape
# Out:
# (506, 13)

# %%
y.shape
# Out:
# (506, 1)

# %% [markdown]
# Then, we split back the target variable

# %% [markdown]
# ## Splitting train/test data

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 1)

# %%
print("Shape of X_train: ",X_train.shape)
print("Shape of X_test: ", X_test.shape)
print("Shape of y_train: ",y_train.shape)
print("Shape of y_test",y_test.shape)
# Out:
# Shape of X_train:  (354, 13)
# Shape of X_test:  (152, 13)
# Shape of y_train:  (354, 1)
# Shape of y_test (152, 1)

# %% [markdown]
# # Data Visualization
#
# Visulising the data that how the data is in corelated with the target variable

# %%
# data distribution analysys
print('Data distribution analysys')
df.columns
columns = ['CHAS', 'RAD']
columns
for v in columns:
    df = df.sort_values(by=[v])
    df[v].value_counts().plot(kind = 'bar')
    plt.title(v)
    plt.show()
# Out:
# Data distribution analysys

# %%
plt.scatter(df['CRIM'],df['MEDV'])
plt.xlabel('CRIM')
plt.ylabel('MEDV')
# Out:
# Text(0, 0.5, 'MEDV')

# %% [markdown]
# How Crime is correlated with price

# %%
plt.scatter(df['ZN'],df['MEDV'])
plt.xlabel('ZN')
plt.ylabel('MEDV')
# Out:
# Text(0, 0.5, 'MEDV')

# %% [markdown]
# How ZN is correlated with price

# %%
sbn.pairplot(df)

# %%
fig, ax = plt.subplots(figsize=(10, 10))
mask = np.tril(df.corr()) #removing lower part of the matrix
sbn.heatmap(df.corr(),
            cmap='RdBu',
            annot=True,
            fmt=".2f",
            cbar_kws= {'orientation': 'vertical'},
            mask=mask)
plt.xticks(range(len(corr.columns)), corr.columns);
plt.yticks(range(len(corr.columns)), corr.columns)
plt.show()

# %%
df.corr()
# Out:
#              CRIM        ZN     INDUS      CHAS       NOX        RM       AGE  \
# CRIM     1.000000 -0.200469  0.406583 -0.055892  0.420972 -0.219247  0.352734
# ZN      -0.200469  1.000000 -0.533828 -0.042697 -0.516604  0.311991 -0.569537
# INDUS    0.406583 -0.533828  1.000000  0.062938  0.763651 -0.391676  0.644779
# CHAS    -0.055892 -0.042697  0.062938  1.000000  0.091203  0.091251  0.086518
# NOX      0.420972 -0.516604  0.763651  0.091203  1.000000 -0.302188  0.731470
# RM      -0.219247  0.311991 -0.391676  0.091251 -0.302188  1.000000 -0.240265
# AGE      0.352734 -0.569537  0.644779  0.086518  0.731470 -0.240265  1.000000
# DIS     -0.379670  0.664408 -0.708027 -0.099176 -0.769230  0.205246 -0.747881
# RAD      0.625505 -0.311948  0.595129 -0.007368  0.611441 -0.209847  0.456022
# TAX      0.582764 -0.314563  0.720760 -0.035587  0.668023 -0.292048  0.506456
# PTRATIO  0.289946 -0.391679  0.383248 -0.121515  0.188933 -0.355501  0.261515
# ...

# %% [markdown]
# ### Finding variables with correlation higher than threshold

# %%
# Create correlation matrix
corr_matrix = df.corr().abs()
high_corr_var=np.where(corr_matrix>0.8)
high_corr_var=[(corr_matrix.columns[x],corr_matrix.columns[y]) for x,y in zip(*high_corr_var) if x!=y and x<y]
high_corr_var
# # Find features with correlation greater than 0.95
#to_drop = [column for column in upper.columns if any(upper[column] > 0.90)]
#to_drop 

# # Drop features 
# df.drop(to_drop, axis=1, inplace=True)
# Out:
# [('RAD', 'TAX')]

# %% [markdown]
# There are 2 variables that have correlation greater than 0.8 - RAD x TAX

# %%
fig, axs = plt.subplots(ncols=7, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for k,v in df.items():
    sns.distplot(v, ax=axs[index])
    index += 1
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)
# Out:
# C:\Users\rantonio\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\rantonio\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# ...

# %%
from sklearn import preprocessing
min_max_scaler = preprocessing.MinMaxScaler()
column_sels = ['LSTAT', 'INDUS', 'NOX', 'PTRATIO', 'RM', 'TAX', 'DIS', 'AGE']
x = df.loc[:,column_sels]
y = df['MEDV']
x = pd.DataFrame(data=min_max_scaler.fit_transform(x), columns=column_sels)
fig, axs = plt.subplots(ncols=4, nrows=2, figsize=(20, 10))
index = 0
axs = axs.flatten()
for i, k in enumerate(column_sels):
    sns.regplot(y=y, x=x[k], ax=axs[i])
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=5.0)
plt.savefig('effect_variables.jpg')

# %% [markdown]
# ## Models

# %% [markdown]
# ### Elastic Net Regression

# %%
from sklearn.linear_model import ElasticNet
from sklearn.metrics import r2_score
# we use elastic net. alpha is the total penalty parameter and l1_ratio is the proportion of alpha to be given to l1 norm
elastic = ElasticNet(alpha = 0.05 , l1_ratio= 0.5, max_iter = 1000) 

#fit the model with train data. 
elastic.fit(X_train,y_train)

# Predicting Cross Validation Score the Test set results
cv_elastic = cross_val_score(estimator = elastic, X = X_train, y = y_train, cv = 10)

# Predicting R2 Score the Train set results
y_pred_elastic_train = elastic.predict(X_train)
r2_score_elastic_train = r2_score(y_train, y_pred_elastic_train)

# Predicting R2 Score the Test set results
y_pred_elastic_test = elastic.predict(X_test)
r2_score_elastic_test = r2_score(y_test, y_pred_elastic_test)

# Predicting RMSE the Test set results
rmse_elastic = (np.sqrt(mean_squared_error(y_test, y_pred_elastic_test)))
mae_elastic = mean_absolute_error(y_test, y_pred_elastic_test)
print("CV: ", cv_elastic.mean())
print('R2_score (train): ', r2_score_elastic_train)
print('R2_score (test): ', r2_score_elastic_test)
print("RMSE: ", rmse_elastic)
print("MAE: ",mae_elastic)
# Out:
# CV:  0.6538109417885252
# R2_score (train):  0.6940278133490484
# R2_score (test):  0.7814073087923936
# RMSE:  4.47604747481921
# MAE:  3.3270327896663723

# %% [markdown]
# ### Linear Regression

# %%
from sklearn.linear_model import LinearRegression
regressor_linear = LinearRegression()
regressor_linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
from sklearn.metrics import r2_score

# Predicting Cross Validation Score the Test set results
cv_linear = cross_val_score(estimator = regressor_linear, X = X_train, y = y_train, cv = 10)

# Predicting R2 Score the Train set results
y_pred_linear_train = regressor_linear.predict(X_train)
r2_score_linear_train = r2_score(y_train, y_pred_linear_train)

# Predicting R2 Score the Test set results
y_pred_linear_test = regressor_linear.predict(X_test)
r2_score_linear_test = r2_score(y_test, y_pred_linear_test)

# Predicting RMSE the Test set results
rmse_linear = (np.sqrt(mean_squared_error(y_test, y_pred_linear_test)))
mae_linear = mean_absolute_error(y_test, y_pred_linear_test)
print("CV: ", cv_linear.mean())
print('R2_score (train): ', r2_score_linear_train)
print('R2_score (test): ', r2_score_linear_test)
print("RMSE: ", rmse_linear)
print("MAE: ",mae_linear)
# Out:
# CV:  0.6681620144824072
# R2_score (train):  0.7103879080674731
# R2_score (test):  0.7836295385076281
# RMSE:  4.45323743719816
# MAE:  3.3446655035987476

# %%
sns.displot(y_test - y_pred_linear_test,legend=False, kde=True)
plt.title("Teste")
# Out:
# Text(0.5, 1.0, 'Teste')

# %% [markdown]
# Distribution of residuals (errors) from the Linear Regression model we've trained

# %% [markdown]
# ### SGDRegressor

# %%
from sklearn.linear_model import SGDRegressor
from sklearn.datasets import make_regression
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import scale
import matplotlib.pyplot as plt

print("Boston housing dataset prediction.")
boston = load_boston()
x, y = boston.data, boston.target

x = scale(x)
y = scale(y)
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=.30)

sgdr = SGDRegressor(alpha=0.0001, epsilon=0.01, eta0=0.1,penalty='elasticnet')
sgdr.fit(xtrain, ytrain)
ypred = sgdr.predict(xtest)
y_pred_sgd_train = sc_y.inverse_transform(sgdr.predict(sc_X.transform(X_train)))
y_pred_sgd_test = sc_y.inverse_transform(sgdr.predict(sc_X.transform(X_test)))

cv_sgd = cross_val_score(estimator = sgdr, X = xtrain, y = ytrain, cv = 10)

#r2_train = r2_score(y_train,y_pred_sgd_train)
r2_train = r2_score(ytrain,sgdr.predict(xtrain))
r2_test = r2_score(y_test,y_pred_sgd_test)
rmse_sgd = (np.sqrt(mean_squared_error(y_test, y_pred_sgd_test)))
mae_sgd =mean_absolute_error(y_test, y_pred_sgd_test)
print('R2_score (train): ', r2_train)
print('R2_score (test): ', r2_test)
print("RMSE: ", rmse_sgd)
print("MAE: ", mae_sgd)
print("CV: ", cv_sgd.mean())

x_ax = range(len(ytest))
plt.plot(x_ax, ytest, label="original")
plt.plot(x_ax, ypred, label="predicted")
plt.title("Boston test and predicted data")
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.legend(loc='best',fancybox=True, shadow=True)
plt.grid(True)
plt.show()
# Out:
# Boston housing dataset prediction.
# R2_score (train):  0.7007085536945254
# R2_score (test):  0.80261690959073
# RMSE:  4.253357016996102
# MAE:  3.413062133729711
# CV:  0.6713102175176484

# %% [markdown]
# ### Support Vector Regression

# %%
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler()
sc_y = StandardScaler()
X_scaled = sc_X.fit_transform(X_train)
y_scaled = sc_y.fit_transform(y_train.reshape(-1,1))

# %%
from sklearn.svm import SVR
regressor_svr = SVR(kernel = 'rbf', gamma = 'scale')
regressor_svr.fit(X_scaled, y_scaled.ravel())
# Out:
# SVR()

# %%
from sklearn.metrics import r2_score

# Predicting Cross Validation Score
cv_svr = cross_val_score(estimator = regressor_svr, X = X_scaled, y = y_scaled.ravel(), cv = 10)

# Predicting R2 Score the Train set results
y_pred_svr_train = sc_y.inverse_transform(regressor_svr.predict(sc_X.transform(X_train)))
r2_score_svr_train = r2_score(y_train, y_pred_svr_train)

# Predicting R2 Score the Test set results
y_pred_svr_test = sc_y.inverse_transform(regressor_svr.predict(sc_X.transform(X_test)))
r2_score_svr_test = r2_score(y_test, y_pred_svr_test)

# Predicting RMSE the Test set results
rmse_svr = (np.sqrt(mean_squared_error(y_test, y_pred_svr_test)))
mae_svr = mean_absolute_error(y_test,  y_pred_svr_test)
print('CV: ', cv_svr.mean())
print('R2_score (train): ', r2_score_svr_train)
print('R2_score (test): ', r2_score_svr_test)
print("RMSE: ", rmse_svr)
print("MAE: ", mae_svr)
# Out:
# CV:  0.7648632961247859
# R2_score (train):  0.8440136429831501
# R2_score (test):  0.872120443137917
# RMSE:  3.423555928417083
# MAE:  2.2506968916650876

# %% [markdown]
# ### Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor
regressor_dt = DecisionTreeRegressor(random_state = 1)
regressor_dt.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
from sklearn.metrics import r2_score

# Predicting Cross Validation Score
cv_dt = cross_val_score(estimator = regressor_dt, X = X_train, y = y_train, cv = 10)

# Predicting R2 Score the Train set results
y_pred_dt_train = regressor_dt.predict(X_train)
r2_score_dt_train = r2_score(y_train, y_pred_dt_train)

# Predicting R2 Score the Test set results
y_pred_dt_test = regressor_dt.predict(X_test)
r2_score_dt_test = r2_score(y_test, y_pred_dt_test)

# Predicting RMSE the Test set results
rmse_dt = (np.sqrt(mean_squared_error(y_test, y_pred_dt_test)))
mae_dt = mean_absolute_error(y_test, y_pred_dt_test)
print('CV: ', cv_dt.mean())
print('R2_score (train): ', r2_score_dt_train)
print('R2_score (test): ', r2_score_dt_test)
print("RMSE: ", rmse_dt)
print("MAE: ", mae_dt)
# Out:
# CV:  0.7216522274237595
# R2_score (train):  1.0
# R2_score (test):  0.8623771688778322
# RMSE:  3.5515841535855515
# MAE:  2.636184210526315

# %% [markdown]
# ### Random Forest Regressor

# %%
#  Fitting the Random Forest Regression to the dataset
from sklearn.ensemble import RandomForestRegressor
regressor_rf = RandomForestRegressor(n_estimators = 500, random_state = 1)
regressor_rf.fit(X_train, y_train.ravel())
# Out:
# RandomForestRegressor(n_estimators=500, random_state=1)

# %%
from sklearn.metrics import r2_score

# Predicting Cross Validation Score
cv_rf = cross_val_score(estimator = regressor_rf, X = X_train, y = y_train.ravel(), cv = 10)

# Predicting R2 Score the Train set results
y_pred_rf_train = regressor_rf.predict(X_train)
r2_score_rf_train = r2_score(y_train, y_pred_rf_train)

# Predicting R2 Score the Test set results
y_pred_rf_test = regressor_rf.predict(X_test)
r2_score_rf_test = r2_score(y_test, y_pred_rf_test)

# Predicting RMSE the Test set results
rmse_rf = (np.sqrt(mean_squared_error(y_test, y_pred_rf_test)))
mae_rf = mean_absolute_error(y_test, y_pred_rf_test)
print('CV: ', cv_rf.mean())
print('R2_score (train): ', r2_score_rf_train)
print('R2_score (test): ', r2_score_rf_test)
print("RMSE: ", rmse_rf)
print("MAE: ", mae_rf)
# Out:
# CV:  0.8531088712837847
# R2_score (train):  0.9806455774686519
# R2_score (test):  0.9101158461438673
# RMSE:  2.8702414567877677
# MAE:  2.203969736842106

# %% [markdown]
# ### Feature importance of the best model

# %%
importances = regressor_rf.feature_importances_
std = np.std([tree.feature_importances_ for tree in regressor_rf.estimators_],axis=0)
indices = np.argsort(importances)[::-1]

variables = ['CRIM', 'ZN', 'INDUS', 'CHAS', 'NOX', 'RM', 'AGE', 'DIS', 'RAD', 'TAX','PTRATIO', 'B', 'LSTAT']
importance_list = []
for f in range(X.shape[1]):
    variable = variables[indices[f]]
    importance_list.append(variable)
    print("%d.%s(%f)" % (f + 1, variable, importances[indices[f]]))
    
plt.figure()
plt.title("Feature importances")
plt.bar(importance_list, importances[indices],
       color="r", yerr=std[indices], align="center")
plt.show()
# Out:
# 1.LSTAT(0.562620)
# 2.RM(0.227093)
# 3.DIS(0.061986)
# 4.CRIM(0.035584)
# 5.NOX(0.027350)
# 6.AGE(0.023829)
# 7.PTRATIO(0.019730)
# 8.B(0.014257)
# 9.TAX(0.013026)
# 10.INDUS(0.007516)
# 11.RAD(0.004282)
# 12.ZN(0.001367)
# 13.CHAS(0.001360)

# %% [markdown]
# LSTAT is the most important variable, accounting for 56% of the variance
# Only 6 of the variables account for more than 1% of the variance, according to the Random Forest model

# %% [markdown]
# ## Gaussian Process Regressor

# %%
import sklearn.gaussian_process as gp
xtrain, xtest, ytrain, ytest = train_test_split(x, y, test_size=.3)
kernel = gp.kernels.ConstantKernel(1.0, (1e-1, 1e3)) * gp.kernels.RBF(10.0, (1e-3, 1e3))
# GP = GaussianProcessRegressor(
#         kernel=Matern(),
#         n_restarts_optimizer=25,
#     )
model = gp.GaussianProcessRegressor(kernel=kernel, n_restarts_optimizer=25, alpha=0.1, normalize_y=True)
model.fit(xtrain, ytrain)
params = model.kernel_.get_params()
#y_pred, std = model.predict(xtest, return_std=True)
y_pred_train = model.predict(xtrain)
#y_pred_test2 = model.predict(xtest)
y_pred_test = sc_y.inverse_transform(model.predict(sc_X.transform(X_test)))
cv_gp = cross_val_score(estimator = model, X = xtrain, y = ytrain, cv = 10)


r2_train_gp = r2_score(ytrain, y_pred_train)
r2_test_gp = r2_score(y_test, y_pred_test)
rmse_gp = (np.sqrt(mean_squared_error(y_test, y_pred_test)))
mae_gp = mean_absolute_error(y_test, y_pred_test)

print("CV score: ",cv_gp.mean())
print('R2_score (train): ', r2_train_gp)
print('R2_score (test): ', r2_test_gp)
print("RMSE: ", rmse_gp)
print("MAE: ", mae_gp)
# Out:
# CV score:  0.8428683513453719
# R2_score (train):  0.9404642550670892
# R2_score (test):  0.9409275209925329
# RMSE:  2.326855768040057
# MAE:  1.7786663770350153

# %%
plt.figure(figsize=(12,12))
plt.scatter(y_test, y_pred_test)
plt.plot([y_test.min(),y_test.max()],[y_test.min(),y_test.max()], color='red', linewidth=3)
plt.xlabel("Actual values")
plt.ylabel("Predicted values")
plt.title("Actual vs predicted values - Gaussian Regression")
plt.savefig('actualvspredicted.jpg')

# %% [markdown]
# ## Comparison of Models

# %%
models = [('Linear Regression', rmse_linear, mae_linear, r2_score_linear_train, r2_score_linear_test, cv_linear.mean()),
          ('SVM', rmse_svr, mae_svr, r2_score_svr_train, r2_score_svr_test, cv_svr.mean()),
          ('Decision Trees', rmse_dt, mae_dt, r2_score_dt_train, r2_score_dt_test, cv_dt.mean()),
          ('Random Forest', rmse_rf, mae_rf, r2_score_rf_train, r2_score_rf_test, cv_rf.mean()),
          ('SGD', rmse_sgd, mae_sgd, r2_train, r2_test, cv_sgd.mean()),
          ('Gaussian Process', rmse_gp, mae_gp, r2_train_gp, r2_test_gp, cv_gp.mean())
         ]

# %%
predict = pd.DataFrame(data = models, columns=['Model', 'RMSE','MAE', 'R2_Score(training)', 'R2_Score(test)', 'Cross-Validation'])
predict
# Out:
#                Model      RMSE       MAE  R2_Score(training)  R2_Score(test)  \
# 0  Linear Regression  4.453237  3.344666            0.710388        0.783630
# 1                SVM  3.423556  2.250697            0.844014        0.872120
# 2     Decision Trees  3.551584  2.636184            1.000000        0.862377
# 3      Random Forest  2.870241  2.203970            0.980646        0.910116
# 4                SGD  4.253357  3.413062            0.700709        0.802617
# 5   Gaussian Process  2.326856  1.778666            0.940464        0.940928
#
#    Cross-Validation
# 0          0.668162
# 1          0.764863
# 2          0.721652
# 3          0.853109
# 4          0.671310
# 5          0.842868

# %%
f, axes = plt.subplots(1,3, figsize=(24,12))

predict.sort_values(by=['R2_Score(training)'], ascending=False, inplace=True)

sns.barplot(x='R2_Score(training)', y='Model', data = predict, palette = reversed(sns.color_palette("Blues_d")), ax = axes[0])
axes[0].set_xlabel('R2 Score (Training)', size=16)
axes[0].set_ylabel('Model')
axes[0].set_xlim(0,1.0)

predict.sort_values(by=['R2_Score(test)'], ascending=False, inplace=True)

sns.barplot(x='R2_Score(test)', y='Model', data = predict, palette = reversed(sns.color_palette("Blues_d")), ax = axes[1])
axes[1].set_xlabel('R2 Score (Test)', size=16)
axes[1].set_ylabel('Model')
axes[1].set_xlim(0,1.0)

predict.sort_values(by=['Cross-Validation'], ascending=False, inplace=True)

sns.barplot(x='Cross-Validation', y='Model', data = predict, palette = reversed(sns.color_palette("Blues_d")), ax = axes[2])
axes[2].set_xlabel('Cross-Validaton Score', size=16)
axes[2].set_ylabel('Model')
axes[2].set_xlim(0,1.0)

plt.suptitle("R2 and CV-Score (the higher the better)", fontsize=16)
plt.savefig('model_comparison1.jpg')
plt.show()

# %%
predict.sort_values(by=['RMSE'], ascending=False, inplace=True)

f, axe = plt.subplots(1,1, figsize=(18,6))
sns.barplot(x='Model', y='RMSE', data=predict, ax = axe,palette='Blues_d')
axe.set_title('RMSE (the lower the better)')
axe.set_xlabel('Model', size=16)
axe.set_ylabel('RMSE', size=16)
plt.savefig('model_comparison_rmse.jpg')
plt.show()

# %%
predict.sort_values(by=['MAE'], ascending=False, inplace=True)

f, axe = plt.subplots(1,1, figsize=(18,6))
sns.barplot(x='Model', y='MAE', data=predict, ax = axe,palette='Blues_d')
axe.set_title('MAE (the lower the better)')
axe.set_xlabel('Model', size=16)
axe.set_ylabel('MAE', size=16)
plt.savefig('model_comparison_mae.jpg')
plt.show()

# %% [markdown]
# And there you have it, **Gaussian Process Regression** was the best method for this dataset, with the best results when looking at every measure:
# - R2 (on the test dataset)
# - MAE
# - RMSE

# %% [markdown]
# For more on Regression Metrics like MAE, RMSE, r2 and others, check: https://scikit-learn.org/stable/modules/model_evaluation.html#regression-metrics
